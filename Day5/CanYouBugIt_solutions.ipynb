# %% [markdown]
# # Can You Bug It?
# ----
#
# By Adam A Miller (Northwestern/CIERA/SkAI)
# 16 Sept 2026
#
# **Version 0.1**

# %% [markdown]
# For this problem we are going to take the `Body` and `Universe` classes from the OOP problem on Day 2 and (eventually) build this out to be a full python package. We will build all the necessary tools one piece at a time.

# %% [markdown]
# We ended Day2 with a plain, nested loop-based force calculation and leapfrog integrator.
#
# There was no config file, no tests, and no docstrings (yet).

# %% [markdown]
# ## Problem 0)
#
# Run this cell to restore the classes from Day2.

# %%
import numpy as np

class Body:
    def __init__(self, m, r, rdot):
        self.m = m
        self.r = np.array(r, dtype=float)
        self.rdot = np.array(rdot, dtype=float)
        self.a = np.zeros_like(self.r)


class Universe:
    def __init__(self):
        self.bodies = []

    def add_body(self, body):
        self.bodies.append(body)

    def compute_acceleration(self):
        G = 6.67430e-11  # gravitational constant
        for body in self.bodies:
            body.a = np.zeros_like(body.r)
        for i, bi in enumerate(self.bodies):
            for j, bj in enumerate(self.bodies):
                if i != j:
                    rij = bj.r - bi.r
                    dist = sum(rij**2) ** 0.5
                    if dist > 0:
                        bi.a += G * bj.m * rij / dist**3

    def leapfrog_step(self, dt):
        for body in self.bodies:
            body.rdot += 0.5 * dt * body.a
        for body in self.bodies:
            body.r += dt * body.rdot
        self.compute_acceleration()
        for body in self.bodies:
            body.rdot += 0.5 * dt * body.a

# %% [markdown]
# ## Problem 1) Create a conda environment for the orrery

# %% [markdown]
# **Problem 1a**
#
# The orrery currently depends on `numpy`. We will later add `pytest` (for this afternoon's lecture), so include that now too.
#
# Write the commands to create and activate a dedicated conda environment
# for this project, and install the packages it needs.

# %% [markdown]
# *write you answer here*
#
# ```bash
# conda create -n orrery python=3.11
# conda activate orrery
# conda install numpy pytest
# ```
#
# *Note* -- `python=3.11` pins the interpreter version too — without it, conda picks
# whatever default it currently ships, which can quietly differ between
# machines and change over time.

# %% [markdown]
# **Problem 1b**
#
# Environment commands typed into a terminal aren't shared when you push
# your code to GitHub. Export the environment to a file that can be
# committed alongside the orrery, and confirm it was written correctly.
#
# *Hint* -- use the `%%writefile` magic function to just type the file contents directly into the cell below

# %%
# %%writefile environment.yml
# name: orrery # complete
# channels:
#   - conda-forge
# dependencies:
#   - python=3.11 # complete
#   - numpy # complete
#   - pytest # complete
# Out:
# Writing environment.yml

# %%
with open("environment.yml") as f:
    print(f.read())
# Out:
# name: orrery # complete
# channels:
#   - conda-forge
# dependencies:
#   - python=3.11 # complete
#   - numpy # complete
#   - pytest # complete

# %% [markdown]
# This is the file a labmate — or you, in a year — would hand to
# `conda env create -f environment.yml` to reproduce this exact
# environment without retyping any commands.

# %% [markdown]
# ## Problem 2) A config file, and a reproducible random system

# %% [markdown]
# **Problem 2a**
#
# `compute_acceleration` currently hardcodes `G` inside the method body.
# That's not good — six months from now, is `6.67430e-11` an intentional
# choice of precision, or just what was typed at the time?
#
# Write a `config.py` containing `G` and the other constants the orrery
# will need (an AU in meters, a day in seconds, and a default random seed),
# and update `Universe.compute_acceleration` to use it instead of a
# hardcoded value.
#
# *Hint* -- bonus points for using `scipy.constants` (or is this not bonus points because more dependencies are being added?)

# %%
# %%writefile config.py
# Physical constants and shared parameters for the digital orrery.

G = 6.67430e-11       # gravitational constant, m^3 kg^-1 s^-2
AU = 1.496e11          # astronomical unit, in meters
DAY = 86400            # seconds in a day
SEED = 1851               # default seed for reproducible random systems
# Out:
# Writing config.py

# %%
import config

class Universe:
    def __init__(self):
        self.bodies = []

    def add_body(self, body):
        self.bodies.append(body)

    def compute_acceleration(self):
        for body in self.bodies:
            body.a = np.zeros_like(body.r)
        for i, bi in enumerate(self.bodies):
            for j, bj in enumerate(self.bodies):
                if i != j:
                    rij = bj.r - bi.r
                    dist = sum(rij**2) ** 0.5
                    if dist > 0:
                        bi.a += config.G * bj.m * rij / dist**3

    def leapfrog_step(self, dt):
        for body in self.bodies:
            body.rdot += 0.5 * dt * body.a
        for body in self.bodies:
            body.r += dt * body.rdot
        self.compute_acceleration()
        for body in self.bodies:
            body.rdot += 0.5 * dt * body.a

# %% [markdown]
# **Problem 2b**
#
# Now use `config.SEED` to build a small, reproducible "asteroid belt": five
# bodies with random masses, positions, and velocities. Confirm that
# building it twice, from the same seed, gives identical bodies — this is
# the seeded-random-numbers test from the reproducibility lecture, applied
# to the orrery.
#
# *Hint* — `np.random.default_rng(seed)` gives you an independent generator
# object; calling `np.random.seed()` instead reseeds a single *global*
# generator, which is easy to accidentally reseed twice in one notebook
# session.

# %%
def make_random_belt(seed, n_bodies=5):
    """Build a Universe with n_bodies random low-mass bodies."""
    rng = np.random.default_rng(seed)
    universe = Universe()
    for _ in range(n_bodies):
        m = rng.uniform(1e15, 1e18)
        r = rng.uniform(2 * config.AU, 4 * config.AU, size=3)
        rdot = rng.uniform(-5e3, 5e3, size=3)
        universe.add_body(Body(m, r, rdot))
    return universe


belt_1 = make_random_belt(config.SEED)
belt_2 = make_random_belt(config.SEED)

for b1, b2 in zip(belt_1.bodies, belt_2.bodies):
    assert b1.m == b2.m
    assert np.array_equal(b1.r, b2.r)
    assert np.array_equal(b1.rdot, b2.rdot)

print("Both belts are identical: the seed made this reproducible.")
# Out:
# Both belts are identical: the seed made this reproducible.

# %% [markdown]
# A belt built *without* passing a seed (or with `np.random.default_rng()`
# and no argument) would differ every time it's built — try it, if you want
# to see the difference directly.

# %% [markdown]
# ## Problem 3) A non-trivial bug, found with pdb

# %% [markdown]
# **Problem 3a**
#
# A labmate added a method to `Universe` to strip out negligible bodies —
# test particles or debris below some mass threshold — before running a
# long integration, to save time. Here's their version:

# %%
class Universe(Universe):
    def remove_low_mass_bodies(self, threshold):
        for i, body in enumerate(self.bodies):
            if body.m < threshold:
                del self.bodies[i]

# %% [markdown]
# Try it on a small universe where two *consecutive* bodies fall below
# the threshold and two do not, and check how many bodies remain.

# %%
test_universe = Universe()
for m in [1e10, 1e10, 1e20, 1e20]:   # first two are below threshold
    test_universe.add_body(Body(m, [0, 0, 0], [0, 0, 0]))

test_universe.remove_low_mass_bodies(threshold=1e15)

print("Bodies remaining:", len(test_universe.bodies))
print("Masses remaining:", [b.m for b in test_universe.bodies])
# Out:
# Bodies remaining: 3
# Masses remaining: [10000000000.0, 1e+20, 1e+20]

# %% [markdown]
# Three bodies remain, not two — one of the low-mass bodies survived.
# No exception was raised, and the result *looks* plausible unless you
# happen to count carefully. This is the kind of bug that's much easier to
# catch with a debugger than by staring at the code.

# %% [markdown]
# **Problem 3b**
#
# Step through `remove_low_mass_bodies` with `pdb` to see why.
#
# *Hint* — the bug is a classic one: the method modifies `self.bodies`
# *while* iterating over it with `enumerate`. Watch what happens to the
# list's indices as items are deleted mid-loop.

# %% [markdown]
# **Diagnosis**
#
# Adding `breakpoint()` just before the `del` line and stepping through with
# `n` shows the problem directly. It's commented out below so this notebook
# can still run start to finish without pausing for input — uncomment it to
# step through interactively yourself.
#
# ```python
# def remove_low_mass_bodies(self, threshold):
#     for i, body in enumerate(self.bodies):
#         if body.m < threshold:
#             # breakpoint()
#             del self.bodies[i]
# ```
#
# Stepping through the four-body test case:
#
# - `i=0`, `body` is the first `1e10` body. It's below threshold, so
#   `del self.bodies[0]` removes it. The list is now three bodies long, and
#   what *was* index 1 (the second `1e10` body) has shifted down to index 0.
# - `enumerate`, however, has already moved on and asks for index `1` next.
#   Index 1 in the *new*, shorter list is now the first `1e20` body — the
#   second `1e10` body at the new index 0 gets skipped entirely.
# - The loop finishes having only ever removed one of the two low-mass
#   bodies, which matches exactly what was observed above.
#
# Inspecting `i` and `self.bodies` at each step in an actual `pdb` session
# (with `p i` and `p self.bodies`) shows this shift directly — the list
# gets shorter under the loop while the index keeps counting up as if it
# hadn't.

# %% [markdown]
# **Problem 3c**
#
# Fix the method, and confirm it now removes both low-mass bodies.

# %%
class Universe(Universe):
    def remove_low_mass_bodies(self, threshold):
        self.bodies = [body for body in self.bodies if body.m >= threshold]


test_universe = Universe()
for m in [1e10, 1e10, 1e20, 1e20]:
    test_universe.add_body(Body(m, [0, 0, 0], [0, 0, 0]))

test_universe.remove_low_mass_bodies(threshold=1e15)

assert len(test_universe.bodies) == 2
assert all(b.m == 1e20 for b in test_universe.bodies)
print("Both low-mass bodies removed correctly.")
# Out:
# Both low-mass bodies removed correctly.

# %% [markdown]
# Building a new list, rather than deleting from the one being iterated
# over, sidesteps the problem entirely: nothing is mutated while the loop
# is reading it.

# %% [markdown]
# ## Problem 4) Profiling and vectorizing `compute_acceleration`

# %% [markdown]
# **Problem 4a**
#
# `compute_acceleration` uses a double Python loop over all pairs of
# bodies. That's fine for five bodies; it may not stay fine for a hundred.
# Build a random system of 150 bodies (reuse `make_random_belt` from
# Problem 2) and time one call to `compute_acceleration` with `%timeit`.

# %%
big_system = make_random_belt(config.SEED, n_bodies=150)

# %timeit big_system.compute_acceleration()
# Out:
# 52.6 ms ± 450 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# **Problem 4b**
#
# Write a vectorized version of `compute_acceleration` using NumPy
# broadcasting instead of the nested Python loop.
#
# *Hint* — the awkward part is the `i == j` (self-interaction) term, which
# divides by a distance of exactly zero. Rather than checking `dist > 0`
# inside a loop, build a boolean mask that excludes the diagonal *before*
# dividing, so no division by zero happens in the first place — this
# avoids the spurious `RuntimeWarning` that a naive vectorization tends to
# produce.

# %%
def compute_acceleration_vectorized(universe):
    """Vectorized replacement for Universe.compute_acceleration."""
    positions = np.array([body.r for body in universe.bodies])
    masses = np.array([body.m for body in universe.bodies])
    n = len(universe.bodies)

    rij = positions[np.newaxis, :, :] - positions[:, np.newaxis, :]
    dist = np.sqrt(np.sum(rij**2, axis=2))

    # exclude the i == j diagonal before dividing, rather than after
    mask = ~np.eye(n, dtype=bool)
    inv_dist3 = np.zeros_like(dist)
    inv_dist3[mask] = 1.0 / dist[mask] ** 3

    acc = config.G * np.sum(
        rij * inv_dist3[:, :, np.newaxis] * masses[np.newaxis, :, np.newaxis],
        axis=1,
    )
    for body, a in zip(universe.bodies, acc):
        body.a = a

# %% [markdown]
# **Problem 4c**
#
# Confirm the vectorized version agrees with the original, then compare
# their speed.

# %%
check_loop = make_random_belt(config.SEED, n_bodies=150)
check_vectorized = make_random_belt(config.SEED, n_bodies=150)

check_loop.compute_acceleration()
compute_acceleration_vectorized(check_vectorized)

for b_loop, b_vec in zip(check_loop.bodies, check_vectorized.bodies):
    assert np.allclose(b_loop.a, b_vec.a)

print("Vectorized and loop-based accelerations agree.")
# Out:
# Vectorized and loop-based accelerations agree.

# %%
# %timeit big_system.compute_acceleration()
# %timeit compute_acceleration_vectorized(big_system)
# Out:
# 52.6 ms ± 337 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 910 μs ± 13.1 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# On most machines this is at least an order of magnitude faster for
# 150 bodies, and the gap grows with the number of bodies — the loop does
# $O(N^2)$ work in Python itself, while the vectorized version does the
# same $O(N^2)$ arithmetic inside NumPy's compiled C loops instead.

# %% [markdown]
# ## Challenge Problem
#
# Profile a full simulation run, not just one call to `compute_acceleration`,
# using `cProfile`. Use the vectorized acceleration from Problem 4 inside a
# `leapfrog_step`-like loop for 200 steps on the 150-body system, and
# identify which function actually dominates the runtime.
#
# *Hint* — you'll need to write a small wrapper function that both updates
# positions/velocities and calls `compute_acceleration_vectorized`, since
# `cProfile.run` profiles a single statement.

# %%
import cProfile


def step_vectorized(universe, dt):
    for body in universe.bodies:
        body.rdot += 0.5 * dt * body.a
    for body in universe.bodies:
        body.r += dt * body.rdot
    compute_acceleration_vectorized(universe)
    for body in universe.bodies:
        body.rdot += 0.5 * dt * body.a


def run_simulation(universe, n_steps, dt):
    compute_acceleration_vectorized(universe)
    for _ in range(n_steps):
        step_vectorized(universe, dt)


profile_system = make_random_belt(config.SEED, n_bodies=150)
cProfile.run("run_simulation(profile_system, 200, config.DAY)", sort="cumtime")
# Out:
#          5781 function calls (5775 primitive calls) in 0.263 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000    0.261    0.261 {built-in method builtins.exec}
#       2/1    0.000    0.000    0.258    0.258 <string>:1(<module>)
#         1    0.000    0.000    0.258    0.258 2912091826.py:14(run_simulation)
#       200    0.069    0.000    0.257    0.001 2912091826.py:4(step_vectorized)
#       201    0.125    0.001    0.189    0.001 2139574791.py:1(compute_acceleration_vectorized)
#       402    0.000    0.000    0.059    0.000 fromnumeric.py:2338(sum)
#       402    0.000    0.000    0.059    0.000 fromnumeric.py:69(_wrapreduction)
#       402    0.058    0.000    0.058    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       402    0.004    0.000    0.004    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.003    0.003 decorator.py:232(fun)
#         1    0.001    0.001    0.003    0.003 history.py:92(only_when_enabled)
#         1    0.000    0.000    0.002    0.002 history.py:1024(writeout_cache)
#         1    0.000    0.000    0.002    0.002 history.py:1008(_writeout_input_cache)
#         2    0.001    0.001    0.002    0.001 {method '__exit__' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.001    0.001 events.py:87(_run)
#       201    0.001    0.000    0.001    0.000 numeric.py:98(zeros_like)
#         2    0.000    0.000    0.001    0.000 {method 'run' of '_contextvars.Context' objects}
#         2    0.000    0.000    0.001    0.000 zmqstream.py:573(_handle_events)
#       201    0.000    0.000    0.001    0.000 _twodim_base_impl.py:176(eye)
#         1    0.000    0.000    0.001    0.001 asyncio.py:206(_handle_events)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:614(_handle_recv)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:546(_run_callback)
#         2    0.000    0.000    0.000    0.000 iostream.py:158(_handle_event)
#         2    0.000    0.000    0.000    0.000 iostream.py:277(<lambda>)
#         2    0.000    0.000    0.000    0.000 iostream.py:279(_really_send)
#         1    0.000    0.000    0.000    0.000 base_events.py:1970(_run_once)
#         2    0.000    0.000    0.000    0.000 socket.py:700(send_multipart)
#         4    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         4    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#       402    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 ioloop.py:750(_run_callback)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:653(_rebuild_io_state)
#        14    0.000    0.000    0.000    0.000 socket.py:623(send)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#        14    0.000    0.000    0.000    0.000 enum.py:1596(__or__)
#   533/529    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#        60    0.000    0.000    0.000    0.000 enum.py:1589(_get_value)
#         1    0.000    0.000    0.000    0.000 selectors.py:540(select)
#         2    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#         1    0.000    0.000    0.000    0.000 inspect.py:3299(bind)
#         6    0.000    0.000    0.000    0.000 enum.py:1607(__and__)
#         1    0.000    0.000    0.000    0.000 {method 'control' of 'select.kqueue' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:3157(_bind)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        26    0.000    0.000    0.000    0.000 enum.py:695(__call__)
#       402    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#       402    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#       402    0.000    0.000    0.000    0.000 fromnumeric.py:2333(_sum_dispatcher)
#       211    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 typing.py:1374(__instancecheck__)
#         6    0.000    0.000    0.000    0.000 typing.py:426(inner)
#         2    0.000    0.000    0.000    0.000 typing.py:1665(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2971(apply_defaults)
#        26    0.000    0.000    0.000    0.000 enum.py:1156(__new__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#       201    0.000    0.000    0.000    0.000 multiarray.py:1106(copyto)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 base_events.py:823(call_soon)
#       201    0.000    0.000    0.000    0.000 numeric.py:92(_zeros_like_dispatcher)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       201    0.000    0.000    0.000    0.000 multiarray.py:115(empty_like)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         2    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#         1    0.000    0.000    0.000    0.000 base_events.py:852(_call_soon)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 contextlib.py:303(helper)
#         1    0.000    0.000    0.000    0.000 threading.py:315(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#         2    0.000    0.000    0.000    0.000 queue.py:112(empty)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 iostream.py:217(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 threading.py:631(clear)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 inspect.py:2918(args)
#         1    0.000    0.000    0.000    0.000 contextlib.py:136(__enter__)
#         1    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         4    0.000    0.000    0.000    0.000 typing.py:1443(__hash__)
#         3    0.000    0.000    0.000    0.000 base_events.py:772(time)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 base_events.py:1955(_add_callback)
#         2    0.000    0.000    0.000    0.000 iostream.py:214(_is_master_process)
#         2    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 threading.py:306(__exit__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         5    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#         1    0.000    0.000    0.000    0.000 inspect.py:2941(kwargs)
#         1    0.000    0.000    0.000    0.000 threading.py:312(_release_save)
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 queue.py:266(_qsize)
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 inspect.py:2828(kind)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         1    0.000    0.000    0.000    0.000 threading.py:318(_is_owned)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.000    0.000 inspect.py:3111(parameters)
#         4    0.000    0.000    0.000    0.000 inspect.py:2816(name)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 iostream.py:256(closed)
#         1    0.000    0.000    0.000    0.000 inspect.py:2910(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:554(_check_closed)
#         1    0.000    0.000    0.000    0.000 base_events.py:2068(get_debug)

# %% [markdown]
# `compute_acceleration_vectorized` still accounts for most of the
# runtime — usually 70-80% of it here — but that's now expected rather
# than a problem: it's doing genuine $O(N^2)$ work, computing every pairwise
# distance and force each step. What's changed from Problem 4 is *why* it
# takes that long: the time is spent inside NumPy's own compiled reduction
# and broadcasting code (`numpy.ufunc.reduce`, `numpy.sum`), not in a
# Python-level loop. The small per-body loops in `step_vectorized` barely
# register by comparison. If this simulation needed to run faster still,
# the acceleration calculation is still where the work is — but getting
# there would now mean a fundamentally different algorithm (like the Fast
# Multipole Method mentioned in the earlier orrery problem set), not
# another round of vectorizing Python loops.
